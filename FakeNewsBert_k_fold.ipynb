# %%
import os
import numpy as np 
import pandas as pd 

from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import precision_score, recall_score, f1_score

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
tf.gfile = tf.io.gfile

import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback, ReduceLROnPlateau

SEED = 1337

# %% [markdown]
# ### Preprocessed Dataset Input

# %%
df_train = pd.read_csv('/content/processed.csv')
df_train.head()
# Out:
#                                             Comments  Label
# 0          হঠাৎ আফগান ক্রিকেট বোর্ড প্রধানের পদত্যাগ    1.0
# 1                           টস হেরে বোলিংয়ে বাংলাদেশ    1.0
# 2                     রাজধানীতে বিশেষ অভিযানে আটক ৪৩    1.0
# 3  উস্কানি রোধে নজরদারি থাকবে সামাজিক যোগাযোগ মাধ...    1.0
# 4     'যেখানে তেল আসত ৭ দিনে, এখন তা আসবে অতি দ্রুত'    1.0

# %% [markdown]
# ### K-fold

# %%
K = 4 # K-fold
skf = StratifiedKFold(n_splits= K, random_state=SEED, shuffle=True)

DISASTER = df_train['Label'] == 1
print('Whole Training Set Shape = {}'.format(df_train.shape))
print('Whole Training Set Unique keyword Count = {}'.format(df_train['Label'].nunique()))
print('Whole Training Set Target Rate (Disaster) {}/{} (Not Disaster)'.format(df_train[DISASTER]['Label'].count(), df_train[~DISASTER]['Label'].count()))

for fold, (trn_idx, val_idx) in enumerate(skf.split(df_train['Comments'], df_train['Label']), 1):
    print('\nFold {} Training Set Shape = {} - Validation Set Shape = {}'.format(fold, df_train.loc[trn_idx, 'Comments'].shape, df_train.loc[val_idx, 'Comments'].shape))
    print('Fold {} Training Set Unique keyword Count = {} - Validation Set Unique keyword Count = {}'.format(fold, df_train.loc[trn_idx, 'Label'].nunique(), df_train.loc[val_idx, 'Label'].nunique()))
# Out:
# Whole Training Set Shape = (8501, 2)
# Whole Training Set Unique keyword Count = 2
# Whole Training Set Target Rate (Disaster) 7202/1299 (Not Disaster)
#
# Fold 1 Training Set Shape = (6375,) - Validation Set Shape = (2126,)
# Fold 1 Training Set Unique keyword Count = 2 - Validation Set Unique keyword Count = 2
#
# Fold 2 Training Set Shape = (6376,) - Validation Set Shape = (2125,)
# Fold 2 Training Set Unique keyword Count = 2 - Validation Set Unique keyword Count = 2
#
# Fold 3 Training Set Shape = (6376,) - Validation Set Shape = (2125,)
# Fold 3 Training Set Unique keyword Count = 2 - Validation Set Unique keyword Count = 2
#
# Fold 4 Training Set Shape = (6376,) - Validation Set Shape = (2125,)
# Fold 4 Training Set Unique keyword Count = 2 - Validation Set Unique keyword Count = 2

# %% [markdown]
# # BERT

# %% [markdown]
# ### Module Installation

# %%
# !pip install bert-tensorflow==1.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bert-tensorflow==1.0.1 in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow==1.0.1) (1.15.0)

# %% [markdown]
# ### BERT Layer

# %%
# %%time
bert_layer = hub.KerasLayer('https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1', trainable=True)
# Out:
# CPU times: user 9.09 s, sys: 1.5 s, total: 10.6 s
# Wall time: 10.5 s

# %% [markdown]
# ### BERT Architecture

# %%
class DisasterDetector:
    
    def __init__(self, bert_layer, max_seq_length=128, lr=0.0001, epochs=15, batch_size=32):
        
        # BERT and Tokenization params
        self.bert_layer = bert_layer
        
        self.max_seq_length = max_seq_length        
        vocab_file = self.bert_layer.resolved_object.vocab_file.asset_path.numpy()
        do_lower_case = self.bert_layer.resolved_object.do_lower_case.numpy()
        self.tokenizer = tokenization.FullTokenizer(vocab_file, do_lower_case)
        
        # Learning control params
        self.lr = lr
        self.epochs = epochs
        self.batch_size = batch_size
        
        self.models = []
        self.scores = {}
        
        
    def encode(self, texts):
                
        all_tokens = []
        all_masks = []
        all_segments = []

        for text in texts:
            text = self.tokenizer.tokenize(text)
            text = text[:self.max_seq_length - 2]
            input_sequence = ['[CLS]'] + text + ['[SEP]']
            pad_len = self.max_seq_length - len(input_sequence)

            tokens = self.tokenizer.convert_tokens_to_ids(input_sequence)
            tokens += [0] * pad_len
            pad_masks = [1] * len(input_sequence) + [0] * pad_len
            segment_ids = [0] * self.max_seq_length

            all_tokens.append(tokens)
            all_masks.append(pad_masks)
            all_segments.append(segment_ids)

        return np.array(all_tokens), np.array(all_masks), np.array(all_segments)
    
    
    def build_model(self):
        
        input_word_ids = Input(shape=(self.max_seq_length,), dtype=tf.int32, name='input_word_ids')
        input_mask = Input(shape=(self.max_seq_length,), dtype=tf.int32, name='input_mask')
        segment_ids = Input(shape=(self.max_seq_length,), dtype=tf.int32, name='segment_ids')    
        
        pooled_output, sequence_output = self.bert_layer([input_word_ids, input_mask, segment_ids])   
        clf_output = sequence_output[:, 0, :]
        out = Dense(1, activation='sigmoid')(clf_output)
        
        model = Model(inputs = [input_word_ids, input_mask, segment_ids], outputs=out)
        optimizer = SGD(learning_rate=self.lr, momentum=0.8)
        metrics = ['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()]
        #tf.keras.metrics.TruePositives(), tf.keras.metrics.TrueNegatives(), tf.keras.metrics.FalsePositives(), tf.keras.metrics.FalseNegatives()
        model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = metrics)
        
        return model
    
    
    def train(self, X):
        
        for fold, (trn_idx, val_idx) in enumerate(skf.split(X['Comments'], X['Label'])):
            
            print('\nFold {}\n'.format(fold))
        
            X_trn_encoded = self.encode(X.loc[trn_idx, 'Comments'].str.lower())
            y_trn = X.loc[trn_idx, 'Label']
            X_val_encoded = self.encode(X.loc[val_idx, 'Comments'].str.lower())
            y_val = X.loc[val_idx, 'Label']
        
            # Callbacks
            metrics = ClassificationReport(train_data=(X_trn_encoded, y_trn), validation_data=(X_val_encoded, y_val))
            
            checkpoint = ModelCheckpoint('FakenewsBERT.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
            earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=1, restore_best_weights=True)
            learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=5, verbose=1, factor=0.2, min_lr=0.001)
            
            callbacks = [earlystop, checkpoint, learning_rate_reduction, metrics]
            
            # Model
            model = self.build_model()        
            history = model.fit(X_trn_encoded, y_trn, validation_data=(X_val_encoded, y_val), callbacks = callbacks, epochs=self.epochs, batch_size=self.batch_size)
            
            #plot_graphs(history, "accuracy")
            #plot_graphs(history, "loss")
            
            """y_pred = argmax(model.predict(X_val_encoded),axis=1)
            y_true = y_val
            target_names = ['class 0', 'class 1']
            print(classification_report(y_true, y_pred, target_names=target_names))

            cm = confusion_matrix(y_true, y_pred)
            f = sns.heatmap(cm, annot=True, fmt='d')
            
            #cm(y_pred)
            
            probs = model.predict_proba(X_val_encoded)
            preds = probs[:,0]
            fpr, tpr, threshold = metrics.roc_curve(testing_labels, preds)
            roc_auc = metrics.auc(fpr, tpr)

            import matplotlib.pyplot as plt
            plt.title('Receiver Operating Characteristic')
            plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
            plt.legend(loc = 'lower right')
            plt.plot([0, 1], [0, 1],'r--')
            plt.xlim([0, 1])
            plt.ylim([0, 1])
            plt.ylabel('True Positive Rate')
            plt.xlabel('False Positive Rate')
            plt.show()
            
            #roc(probs)"""
            
            self.models.append(model)
            self.scores[fold] = {
                'train': {
                    'precision': metrics.train_precision_scores,
                    'recall': metrics.train_recall_scores,
                    'f1': metrics.train_f1_scores                    
                },
                'validation': {
                    'precision': metrics.val_precision_scores,
                    'recall': metrics.val_recall_scores,
                    'f1': metrics.val_f1_scores                    
                }
            }
                    
                
    def plot_learning_curve(self):
        
        fig, axes = plt.subplots(nrows=K, ncols=2, figsize=(20, K * 6), dpi=100)
    
        for i in range(K):
            
            # Classification Report curve
            sns.lineplot(x=np.arange(1, self.epochs + 1), y=clf.models[i].history.history['val_accuracy'], ax=axes[i][0], label='val_accuracy')
            sns.lineplot(x=np.arange(1, self.epochs + 1), y=clf.scores[i]['validation']['precision'], ax=axes[i][0], label='val_precision')
            sns.lineplot(x=np.arange(1, self.epochs + 1), y=clf.scores[i]['validation']['recall'], ax=axes[i][0], label='val_recall')
            sns.lineplot(x=np.arange(1, self.epochs + 1), y=clf.scores[i]['validation']['f1'], ax=axes[i][0], label='val_f1')        

            axes[i][0].legend() 
            axes[i][0].set_title('Fold {} Validation Classification Report'.format(i), fontsize=14)

            # Loss curve
            sns.lineplot(x=np.arange(1, self.epochs + 1), y=clf.models[0].history.history['loss'], ax=axes[i][1], label='train_loss')
            sns.lineplot(x=np.arange(1, self.epochs + 1), y=clf.models[0].history.history['val_loss'], ax=axes[i][1], label='val_loss')

            axes[i][1].legend() 
            axes[i][1].set_title('Fold {} Train / Validation Loss'.format(i), fontsize=14)

            for j in range(2):
                axes[i][j].set_xlabel('Epoch', size=12)
                axes[i][j].tick_params(axis='x', labelsize=12)
                axes[i][j].tick_params(axis='y', labelsize=12)

        plt.show()
        
        
    def predict(self, X):
        
        X_test_encoded = self.encode(X['Comments'].str.lower())
        y_pred = np.zeros((X_test_encoded[0].shape[0], 1))

        for model in self.models:
            y_pred += model.predict(X_test_encoded) / len(self.models)

        return y_pred

# %% [markdown]
# ### Classification Report on epoch end

# %%
class ClassificationReport(Callback):
    
    def __init__(self, train_data=(), validation_data=()):
        super(Callback, self).__init__()
        
        self.X_train, self.y_train = train_data
        self.train_precision_scores = []
        self.train_recall_scores = []
        self.train_f1_scores = []
        
        self.X_val, self.y_val = validation_data
        self.val_precision_scores = []
        self.val_recall_scores = []
        self.val_f1_scores = [] 
               
    def on_epoch_end(self, epoch, logs={}):
        train_predictions = np.round(self.model.predict(self.X_train, verbose=0))        
        train_precision = precision_score(self.y_train, train_predictions, average='macro')
        train_recall = recall_score(self.y_train, train_predictions, average='macro')
        train_f1 = f1_score(self.y_train, train_predictions, average='macro')
        self.train_precision_scores.append(train_precision)        
        self.train_recall_scores.append(train_recall)
        self.train_f1_scores.append(train_f1)
        
        val_predictions = np.round(self.model.predict(self.X_val, verbose=0))
        val_precision = precision_score(self.y_val, val_predictions, average='macro')
        val_recall = recall_score(self.y_val, val_predictions, average='macro')
        val_f1 = f1_score(self.y_val, val_predictions, average='macro')
        self.val_precision_scores.append(val_precision)        
        self.val_recall_scores.append(val_recall)        
        self.val_f1_scores.append(val_f1)
        
        print('\nEpoch: {} - Training Precision: {:.6} - Training Recall: {:.6} - Training F1: {:.6}'.format(epoch + 1, train_precision, train_recall, train_f1))
        print('Epoch: {} - Validation Precision: {:.6} - Validation Recall: {:.6} - Validation F1: {:.6}'.format(epoch + 1, val_precision, val_recall, val_f1))

# %% [markdown]
# ### Initialize Training

# %%
from bert import tokenization

clf = DisasterDetector(bert_layer, max_seq_length=128, lr = 0.0001, epochs = 10, batch_size = 32)
clf.train(df_train)
# Out:
# Fold 0
#
# Epoch 1/10
# 200/200 [==============================] - ETA: 0s - loss: 0.3928 - accuracy: 0.8474 - precision: 0.8473 - recall: 1.0000 - auc: 0.7149
# Epoch 1: val_loss improved from inf to 0.33489, saving model to FakenewsBERT.h5
#
# Epoch: 1 - Training Precision: 0.861562 - Training Recall: 0.503501 - Training F1: 0.466
# Epoch: 1 - Validation Precision: 0.423565 - Validation Recall: 0.5 - Validation F1: 0.45862
# 200/200 [==============================] - 283s 1s/step - loss: 0.3928 - accuracy: 0.8474 - precision: 0.8473 - recall: 1.0000 - auc: 0.7149 - val_loss: 0.3349 - val_accuracy: 0.8471 - val_precision: 0.8471 - val_recall: 1.0000 - val_auc: 0.8357 - lr: 1.0000e-04
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 200/200 [==============================] - ETA: 0s - loss: 0.2954 - accuracy: 0.8916 - precision: 0.8908 - recall: 0.9939 - auc: 0.8577
# Epoch 2: val_loss improved from 0.33489 to 0.26745, saving model to FakenewsBERT.h5
#
# Epoch: 2 - Training Precision: 0.871851 - Training Recall: 0.738689 - Training F1: 0.783812
# Epoch: 2 - Validation Precision: 0.880946 - Validation Recall: 0.758531 - Validation F1: 0.802336
# 200/200 [==============================] - 279s 1s/step - loss: 0.2954 - accuracy: 0.8916 - precision: 0.8908 - recall: 0.9939 - auc: 0.8577 - val_loss: 0.2674 - val_accuracy: 0.9135 - val_precision: 0.9213 - val_recall: 0.9817 - val_auc: 0.8754 - lr: 1.0000e-04
# Epoch 3/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9092 - precision: 0.9153 - recall: 0.9839 - auc: 0.8845
# Epoch 3: val_loss improved from 0.26745 to 0.24817, saving model to FakenewsBERT.h5
#
# Epoch: 3 - Training Precision: 0.885314 - Training Recall: 0.764727 - Training F1: 0.808414
# Epoch: 3 - Validation Precision: 0.884843 - Validation Recall: 0.763424 - Validation F1: 0.807254
# 200/200 [==============================] - 280s 1s/step - loss: 0.2558 - accuracy: 0.9092 - precision: 0.9153 - recall: 0.9839 - auc: 0.8845 - val_loss: 0.2482 - val_accuracy: 0.9153 - val_precision: 0.9228 - val_recall: 0.9822 - val_auc: 0.8927 - lr: 1.0000e-04
# Epoch 4/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.9145 - precision: 0.9218 - recall: 0.9824 - auc: 0.8961
# Epoch 4: val_loss improved from 0.24817 to 0.23962, saving model to FakenewsBERT.h5
#
# Epoch: 4 - Training Precision: 0.915875 - Training Recall: 0.745321 - Training F1: 0.799224
# Epoch: 4 - Validation Precision: 0.907081 - Validation Recall: 0.733742 - Validation F1: 0.786971
# 200/200 [==============================] - 280s 1s/step - loss: 0.2387 - accuracy: 0.9145 - precision: 0.9218 - recall: 0.9824 - auc: 0.8961 - val_loss: 0.2396 - val_accuracy: 0.9120 - val_precision: 0.9130 - val_recall: 0.9906 - val_auc: 0.8997 - lr: 1.0000e-04
# Epoch 5/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2274 - accuracy: 0.9184 - precision: 0.9258 - recall: 0.9824 - auc: 0.9063
# Epoch 5: val_loss improved from 0.23962 to 0.23377, saving model to FakenewsBERT.h5
#
# Epoch: 5 - Training Precision: 0.876781 - Training Recall: 0.806341 - Training F1: 0.83596
# Epoch: 5 - Validation Precision: 0.865436 - Validation Recall: 0.797871 - Validation F1: 0.826307
# 200/200 [==============================] - 280s 1s/step - loss: 0.2274 - accuracy: 0.9184 - precision: 0.9258 - recall: 0.9824 - auc: 0.9063 - val_loss: 0.2338 - val_accuracy: 0.9182 - val_precision: 0.9348 - val_recall: 0.9711 - val_auc: 0.9051 - lr: 1.0000e-04
# Epoch 6/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9222 - precision: 0.9296 - recall: 0.9826 - auc: 0.9151
# Epoch 6: val_loss improved from 0.23377 to 0.22281, saving model to FakenewsBERT.h5
#
# Epoch: 6 - Training Precision: 0.907979 - Training Recall: 0.787811 - Training F1: 0.832586
# Epoch: 6 - Validation Precision: 0.89823 - Validation Recall: 0.77838 - Validation F1: 0.822595
# 200/200 [==============================] - 257s 1s/step - loss: 0.2168 - accuracy: 0.9222 - precision: 0.9296 - recall: 0.9826 - auc: 0.9151 - val_loss: 0.2228 - val_accuracy: 0.9214 - val_precision: 0.9273 - val_recall: 0.9845 - val_auc: 0.9096 - lr: 1.0000e-04
# Epoch 7/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9247 - precision: 0.9328 - recall: 0.9819 - auc: 0.9216
# Epoch 7: val_loss improved from 0.22281 to 0.21962, saving model to FakenewsBERT.h5
#
# Epoch: 7 - Training Precision: 0.889526 - Training Recall: 0.822432 - Training F1: 0.851117
# Epoch: 7 - Validation Precision: 0.868012 - Validation Recall: 0.804025 - Validation F1: 0.831279
# 200/200 [==============================] - 279s 1s/step - loss: 0.2080 - accuracy: 0.9247 - precision: 0.9328 - recall: 0.9819 - auc: 0.9216 - val_loss: 0.2196 - val_accuracy: 0.9200 - val_precision: 0.9368 - val_recall: 0.9711 - val_auc: 0.9102 - lr: 1.0000e-04
# Epoch 8/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9272 - precision: 0.9350 - recall: 0.9824 - auc: 0.9278
# Epoch 8: val_loss did not improve from 0.21962
#
# Epoch: 8 - Training Precision: 0.846288 - Training Recall: 0.86721 - Training F1: 0.856232
# Epoch: 8 - Validation Precision: 0.828126 - Validation Recall: 0.833071 - Validation F1: 0.830567
# 200/200 [==============================] - 277s 1s/step - loss: 0.2008 - accuracy: 0.9272 - precision: 0.9350 - recall: 0.9824 - auc: 0.9278 - val_loss: 0.2397 - val_accuracy: 0.9116 - val_precision: 0.9493 - val_recall: 0.9461 - val_auc: 0.9133 - lr: 1.0000e-04
# Epoch 9/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9304 - precision: 0.9395 - recall: 0.9809 - auc: 0.9316
# Epoch 9: val_loss did not improve from 0.21962
#
# Epoch: 9 - Training Precision: 0.93872 - Training Recall: 0.777695 - Training F1: 0.83236
# Epoch: 9 - Validation Precision: 0.917508 - Validation Recall: 0.758635 - Validation F1: 0.811257
# 200/200 [==============================] - 277s 1s/step - loss: 0.1946 - accuracy: 0.9304 - precision: 0.9395 - recall: 0.9809 - auc: 0.9316 - val_loss: 0.2251 - val_accuracy: 0.9200 - val_precision: 0.9206 - val_recall: 0.9911 - val_auc: 0.9151 - lr: 1.0000e-04
# Epoch 10/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9347 - precision: 0.9419 - recall: 0.9837 - auc: 0.9384
# Epoch 10: val_loss improved from 0.21962 to 0.20778, saving model to FakenewsBERT.h5
#
# Epoch: 10 - Training Precision: 0.921607 - Training Recall: 0.831445 - Training F1: 0.868444
# Epoch: 10 - Validation Precision: 0.884163 - Validation Recall: 0.802464 - Validation F1: 0.835896
# 200/200 [==============================] - 258s 1s/step - loss: 0.1853 - accuracy: 0.9347 - precision: 0.9419 - recall: 0.9837 - auc: 0.9384 - val_loss: 0.2078 - val_accuracy: 0.9238 - val_precision: 0.9357 - val_recall: 0.9772 - val_auc: 0.9185 - lr: 1.0000e-04
#
# Fold 1
#
# Epoch 1/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2638 - accuracy: 0.8990 - precision_1: 0.9031 - recall_1: 0.9867 - auc_1: 0.8919
# Epoch 1: val_loss improved from inf to 0.19145, saving model to FakenewsBERT.h5
#
# Epoch: 1 - Training Precision: 0.901698 - Training Recall: 0.81102 - Training F1: 0.847664
# Epoch: 1 - Validation Precision: 0.881747 - Validation Recall: 0.831798 - Validation F1: 0.854045
# 200/200 [==============================] - 268s 1s/step - loss: 0.2638 - accuracy: 0.8990 - precision_1: 0.9031 - recall_1: 0.9867 - auc_1: 0.8919 - val_loss: 0.1914 - val_accuracy: 0.9294 - val_precision_1: 0.9460 - val_recall_1: 0.9722 - val_auc_1: 0.9412 - lr: 1.0000e-04
# Epoch 2/10
# 200/200 [==============================] - ETA: 0s - loss: 0.2035 - accuracy: 0.9296 - precision_1: 0.9392 - recall_1: 0.9804 - auc_1: 0.9255
# Epoch 2: val_loss improved from 0.19145 to 0.18965, saving model to FakenewsBERT.h5
#
# Epoch: 2 - Training Precision: 0.895187 - Training Recall: 0.86434 - Training F1: 0.878778
# Epoch: 2 - Validation Precision: 0.868972 - Validation Recall: 0.877326 - Validation F1: 0.873073
# 200/200 [==============================] - 280s 1s/step - loss: 0.2035 - accuracy: 0.9296 - precision_1: 0.9392 - recall_1: 0.9804 - auc_1: 0.9255 - val_loss: 0.1896 - val_accuracy: 0.9336 - val_precision_1: 0.9632 - val_recall_1: 0.9584 - val_auc_1: 0.9435 - lr: 1.0000e-04
# Epoch 3/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9344 - precision_1: 0.9448 - recall_1: 0.9798 - auc_1: 0.9338
# Epoch 3: val_loss improved from 0.18965 to 0.18282, saving model to FakenewsBERT.h5
#
# Epoch: 3 - Training Precision: 0.928528 - Training Recall: 0.799566 - Training F1: 0.847375
# Epoch: 3 - Validation Precision: 0.914736 - Validation Recall: 0.810961 - Validation F1: 0.851821
# 200/200 [==============================] - 259s 1s/step - loss: 0.1896 - accuracy: 0.9344 - precision_1: 0.9448 - recall_1: 0.9798 - auc_1: 0.9338 - val_loss: 0.1828 - val_accuracy: 0.9327 - val_precision_1: 0.9377 - val_recall_1: 0.9861 - val_auc_1: 0.9466 - lr: 1.0000e-04
# Epoch 4/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9407 - precision_1: 0.9495 - recall_1: 0.9822 - auc_1: 0.9439
# Epoch 4: val_loss improved from 0.18282 to 0.18269, saving model to FakenewsBERT.h5
#
# Epoch: 4 - Training Precision: 0.938148 - Training Recall: 0.80077 - Training F1: 0.850953
# Epoch: 4 - Validation Precision: 0.920193 - Validation Recall: 0.81025 - Validation F1: 0.852992
# 200/200 [==============================] - 280s 1s/step - loss: 0.1746 - accuracy: 0.9407 - precision_1: 0.9495 - recall_1: 0.9822 - auc_1: 0.9439 - val_loss: 0.1827 - val_accuracy: 0.9336 - val_precision_1: 0.9373 - val_recall_1: 0.9878 - val_auc_1: 0.9455 - lr: 1.0000e-04
# Epoch 5/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9429 - precision_1: 0.9498 - recall_1: 0.9846 - auc_1: 0.9473
# Epoch 5: val_loss did not improve from 0.18269
#
# Epoch: 5 - Training Precision: 0.946787 - Training Recall: 0.788312 - Training F1: 0.843142
# Epoch: 5 - Validation Precision: 0.925755 - Validation Recall: 0.794663 - Validation F1: 0.842832
# 200/200 [==============================] - 254s 1s/step - loss: 0.1673 - accuracy: 0.9429 - precision_1: 0.9498 - recall_1: 0.9846 - auc_1: 0.9473 - val_loss: 0.1880 - val_accuracy: 0.9308 - val_precision_1: 0.9321 - val_recall_1: 0.9906 - val_auc_1: 0.9481 - lr: 1.0000e-04
# Epoch 6/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9457 - precision_1: 0.9550 - recall_1: 0.9822 - auc_1: 0.9553
# Epoch 6: val_loss improved from 0.18269 to 0.17399, saving model to FakenewsBERT.h5
#
# Epoch: 6 - Training Precision: 0.941597 - Training Recall: 0.898976 - Training F1: 0.918631
# Epoch: 6 - Validation Precision: 0.888869 - Validation Recall: 0.87896 - Validation F1: 0.883812
# 200/200 [==============================] - 256s 1s/step - loss: 0.1567 - accuracy: 0.9457 - precision_1: 0.9550 - recall_1: 0.9822 - auc_1: 0.9553 - val_loss: 0.1740 - val_accuracy: 0.9407 - val_precision_1: 0.9625 - val_recall_1: 0.9678 - val_auc_1: 0.9504 - lr: 1.0000e-04
# Epoch 7/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9551 - precision_1: 0.9614 - recall_1: 0.9867 - auc_1: 0.9626
# Epoch 7: val_loss did not improve from 0.17399
#
# Epoch: 7 - Training Precision: 0.932461 - Training Recall: 0.922587 - Training F1: 0.927435
# Epoch: 7 - Validation Precision: 0.858706 - Validation Recall: 0.88452 - Validation F1: 0.870862
# 200/200 [==============================] - 253s 1s/step - loss: 0.1399 - accuracy: 0.9551 - precision_1: 0.9614 - recall_1: 0.9867 - auc_1: 0.9626 - val_loss: 0.1818 - val_accuracy: 0.9308 - val_precision_1: 0.9667 - val_recall_1: 0.9511 - val_auc_1: 0.9507 - lr: 1.0000e-04
# Epoch 8/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9572 - precision_1: 0.9630 - recall_1: 0.9874 - auc_1: 0.9679
# Epoch 8: val_loss improved from 0.17399 to 0.16747, saving model to FakenewsBERT.h5
#
# Epoch: 8 - Training Precision: 0.958236 - Training Recall: 0.886924 - Training F1: 0.918074
# Epoch: 8 - Validation Precision: 0.916402 - Validation Recall: 0.859666 - Validation F1: 0.88486
# 200/200 [==============================] - 279s 1s/step - loss: 0.1313 - accuracy: 0.9572 - precision_1: 0.9630 - recall_1: 0.9874 - auc_1: 0.9679 - val_loss: 0.1675 - val_accuracy: 0.9445 - val_precision_1: 0.9541 - val_recall_1: 0.9817 - val_auc_1: 0.9513 - lr: 1.0000e-04
# Epoch 9/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9588 - precision_1: 0.9649 - recall_1: 0.9872 - auc_1: 0.9679
# Epoch 9: val_loss did not improve from 0.16747
#
# Epoch: 9 - Training Precision: 0.965402 - Training Recall: 0.924174 - Training F1: 0.943336
# Epoch: 9 - Validation Precision: 0.898236 - Validation Recall: 0.880903 - Validation F1: 0.889264
# 200/200 [==============================] - 255s 1s/step - loss: 0.1268 - accuracy: 0.9588 - precision_1: 0.9649 - recall_1: 0.9872 - auc_1: 0.9679 - val_loss: 0.1683 - val_accuracy: 0.9440 - val_precision_1: 0.9626 - val_recall_1: 0.9717 - val_auc_1: 0.9509 - lr: 1.0000e-04
# Epoch 10/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9650 - precision_1: 0.9702 - recall_1: 0.9891 - auc_1: 0.9766
# Epoch 10: val_loss did not improve from 0.16747
#
# Epoch: 10 - Training Precision: 0.865528 - Training Recall: 0.937178 - Training F1: 0.895792
# Epoch: 10 - Validation Precision: 0.783675 - Validation Recall: 0.883857 - Validation F1: 0.818991
# 200/200 [==============================] - 277s 1s/step - loss: 0.1110 - accuracy: 0.9650 - precision_1: 0.9702 - recall_1: 0.9891 - auc_1: 0.9766 - val_loss: 0.2572 - val_accuracy: 0.8889 - val_precision_1: 0.9757 - val_recall_1: 0.8912 - val_auc_1: 0.9513 - lr: 1.0000e-04
#
# Fold 2
#
# Epoch 1/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9269 - precision_2: 0.9359 - recall_2: 0.9809 - auc_2: 0.9425
# Epoch 1: val_loss improved from inf to 0.14388, saving model to FakenewsBERT.h5
#
# Epoch: 1 - Training Precision: 0.955441 - Training Recall: 0.845643 - Training F1: 0.889514
# Epoch: 1 - Validation Precision: 0.964 - Validation Recall: 0.828397 - Validation F1: 0.879462
# 200/200 [==============================] - 268s 1s/step - loss: 0.1956 - accuracy: 0.9269 - precision_2: 0.9359 - recall_2: 0.9809 - auc_2: 0.9425 - val_loss: 0.1439 - val_accuracy: 0.9464 - val_precision_2: 0.9418 - val_recall_2: 0.9983 - val_auc_2: 0.9711 - lr: 1.0000e-04
# Epoch 2/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9562 - precision_2: 0.9655 - recall_2: 0.9835 - auc_2: 0.9665
# Epoch 2: val_loss improved from 0.14388 to 0.11454, saving model to FakenewsBERT.h5
#
# Epoch: 2 - Training Precision: 0.945574 - Training Recall: 0.910359 - Training F1: 0.926854
# Epoch: 2 - Validation Precision: 0.958004 - Validation Recall: 0.885897 - Validation F1: 0.917338
# 200/200 [==============================] - 258s 1s/step - loss: 0.1349 - accuracy: 0.9562 - precision_2: 0.9655 - recall_2: 0.9835 - auc_2: 0.9665 - val_loss: 0.1145 - val_accuracy: 0.9605 - val_precision_2: 0.9613 - val_recall_2: 0.9933 - val_auc_2: 0.9752 - lr: 1.0000e-04
# Epoch 3/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9603 - precision_2: 0.9695 - recall_2: 0.9841 - auc_2: 0.9753
# Epoch 3: val_loss did not improve from 0.11454
#
# Epoch: 3 - Training Precision: 0.958796 - Training Recall: 0.852081 - Training F1: 0.895138
# Epoch: 3 - Validation Precision: 0.960276 - Validation Recall: 0.820427 - Validation F1: 0.872312
# 200/200 [==============================] - 277s 1s/step - loss: 0.1162 - accuracy: 0.9603 - precision_2: 0.9695 - recall_2: 0.9841 - auc_2: 0.9753 - val_loss: 0.1599 - val_accuracy: 0.9435 - val_precision_2: 0.9393 - val_recall_2: 0.9978 - val_auc_2: 0.9694 - lr: 1.0000e-04
# Epoch 4/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9649 - precision_2: 0.9711 - recall_2: 0.9880 - auc_2: 0.9784
# Epoch 4: val_loss improved from 0.11454 to 0.11260, saving model to FakenewsBERT.h5
#
# Epoch: 4 - Training Precision: 0.970915 - Training Recall: 0.929975 - Training F1: 0.949034
# Epoch: 4 - Validation Precision: 0.964093 - Validation Recall: 0.880855 - Validation F1: 0.916385
# 200/200 [==============================] - 258s 1s/step - loss: 0.1096 - accuracy: 0.9649 - precision_2: 0.9711 - recall_2: 0.9880 - auc_2: 0.9784 - val_loss: 0.1126 - val_accuracy: 0.9605 - val_precision_2: 0.9593 - val_recall_2: 0.9956 - val_auc_2: 0.9770 - lr: 1.0000e-04
# Epoch 5/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9699 - precision_2: 0.9762 - recall_2: 0.9885 - auc_2: 0.9834
# Epoch 5: val_loss did not improve from 0.11260
#
# Epoch: 5 - Training Precision: 0.974023 - Training Recall: 0.931978 - Training F1: 0.951523
# Epoch: 5 - Validation Precision: 0.960253 - Validation Recall: 0.871346 - Validation F1: 0.908756
# 200/200 [==============================] - 277s 1s/step - loss: 0.0921 - accuracy: 0.9699 - precision_2: 0.9762 - recall_2: 0.9885 - auc_2: 0.9834 - val_loss: 0.1162 - val_accuracy: 0.9572 - val_precision_2: 0.9562 - val_recall_2: 0.9950 - val_auc_2: 0.9757 - lr: 1.0000e-04
# Epoch 6/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9769 - precision_2: 0.9817 - recall_2: 0.9913 - auc_2: 0.9878
# Epoch 6: val_loss improved from 0.11260 to 0.10826, saving model to FakenewsBERT.h5
#
# Epoch: 6 - Training Precision: 0.976253 - Training Recall: 0.966986 - Training F1: 0.971549
# Epoch: 6 - Validation Precision: 0.941871 - Validation Recall: 0.911239 - Validation F1: 0.925707
# 200/200 [==============================] - 258s 1s/step - loss: 0.0778 - accuracy: 0.9769 - precision_2: 0.9817 - recall_2: 0.9913 - auc_2: 0.9878 - val_loss: 0.1083 - val_accuracy: 0.9628 - val_precision_2: 0.9710 - val_recall_2: 0.9856 - val_auc_2: 0.9765 - lr: 1.0000e-04
# Epoch 7/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9784 - precision_2: 0.9828 - recall_2: 0.9919 - auc_2: 0.9899
# Epoch 7: val_loss did not improve from 0.10826
#
# Epoch: 7 - Training Precision: 0.977799 - Training Recall: 0.952932 - Training F1: 0.964858
# Epoch: 7 - Validation Precision: 0.944297 - Validation Recall: 0.871923 - Validation F1: 0.903286
# 200/200 [==============================] - 253s 1s/step - loss: 0.0685 - accuracy: 0.9784 - precision_2: 0.9828 - recall_2: 0.9919 - auc_2: 0.9899 - val_loss: 0.1340 - val_accuracy: 0.9539 - val_precision_2: 0.9570 - val_recall_2: 0.9900 - val_auc_2: 0.9707 - lr: 1.0000e-04
# Epoch 8/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0577 - accuracy: 0.9821 - precision_2: 0.9859 - recall_2: 0.9932 - auc_2: 0.9925
# Epoch 8: val_loss did not improve from 0.10826
#
# Epoch: 8 - Training Precision: 0.987679 - Training Recall: 0.969023 - Training F1: 0.978073
# Epoch: 8 - Validation Precision: 0.955848 - Validation Recall: 0.884081 - Validation F1: 0.91537
# 200/200 [==============================] - 254s 1s/step - loss: 0.0577 - accuracy: 0.9821 - precision_2: 0.9859 - recall_2: 0.9932 - auc_2: 0.9925 - val_loss: 0.1214 - val_accuracy: 0.9595 - val_precision_2: 0.9608 - val_recall_2: 0.9928 - val_auc_2: 0.9751 - lr: 1.0000e-04
# Epoch 9/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9834 - precision_2: 0.9868 - recall_2: 0.9937 - auc_2: 0.9935
# Epoch 9: val_loss did not improve from 0.10826
#
# Epoch: 9 - Training Precision: 0.991022 - Training Recall: 0.978541 - Training F1: 0.984658
# Epoch: 9 - Validation Precision: 0.95654 - Validation Recall: 0.894573 - Validation F1: 0.922157
# 200/200 [==============================] - 254s 1s/step - loss: 0.0513 - accuracy: 0.9834 - precision_2: 0.9868 - recall_2: 0.9937 - auc_2: 0.9935 - val_loss: 0.1225 - val_accuracy: 0.9624 - val_precision_2: 0.9644 - val_recall_2: 0.9922 - val_auc_2: 0.9704 - lr: 1.0000e-04
# Epoch 10/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9875 - precision_2: 0.9892 - recall_2: 0.9961 - auc_2: 0.9950
# Epoch 10: val_loss did not improve from 0.10826
#
# Epoch: 10 - Training Precision: 0.989015 - Training Recall: 0.947361 - Training F1: 0.966791
# Epoch: 10 - Validation Precision: 0.966785 - Validation Recall: 0.843782 - Validation F1: 0.891735
# 200/200 [==============================] - 253s 1s/step - loss: 0.0419 - accuracy: 0.9875 - precision_2: 0.9892 - recall_2: 0.9961 - auc_2: 0.9950 - val_loss: 0.1652 - val_accuracy: 0.9511 - val_precision_2: 0.9468 - val_recall_2: 0.9983 - val_auc_2: 0.9646 - lr: 1.0000e-04
#
# Fold 3
#
# Epoch 1/10
# 200/200 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 0.9542 - precision_3: 0.9579 - recall_3: 0.9894 - auc_3: 0.9746
# Epoch 1: val_loss improved from inf to 0.06520, saving model to FakenewsBERT.h5
#
# Epoch: 1 - Training Precision: 0.979898 - Training Recall: 0.947841 - Training F1: 0.963027
# Epoch: 1 - Validation Precision: 0.983447 - Validation Recall: 0.952457 - Validation F1: 0.967172
# 200/200 [==============================] - 270s 1s/step - loss: 0.1339 - accuracy: 0.9542 - precision_3: 0.9579 - recall_3: 0.9894 - auc_3: 0.9746 - val_loss: 0.0652 - val_accuracy: 0.9835 - val_precision_3: 0.9836 - val_recall_3: 0.9972 - val_auc_3: 0.9949 - lr: 1.0000e-04
# Epoch 2/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9771 - precision_3: 0.9811 - recall_3: 0.9920 - auc_3: 0.9875
# Epoch 2: val_loss improved from 0.06520 to 0.06074, saving model to FakenewsBERT.h5
#
# Epoch: 2 - Training Precision: 0.97242 - Training Recall: 0.969233 - Training F1: 0.970818
# Epoch: 2 - Validation Precision: 0.97019 - Validation Recall: 0.973739 - Validation F1: 0.971954
# 200/200 [==============================] - 280s 1s/step - loss: 0.0761 - accuracy: 0.9771 - precision_3: 0.9811 - recall_3: 0.9920 - auc_3: 0.9875 - val_loss: 0.0607 - val_accuracy: 0.9854 - val_precision_3: 0.9922 - val_recall_3: 0.9906 - val_auc_3: 0.9945 - lr: 1.0000e-04
# Epoch 3/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9837 - precision_3: 0.9853 - recall_3: 0.9956 - auc_3: 0.9897
# Epoch 3: val_loss did not improve from 0.06074
#
# Epoch: 3 - Training Precision: 0.990378 - Training Recall: 0.958049 - Training F1: 0.973379
# Epoch: 3 - Validation Precision: 0.981606 - Validation Recall: 0.934274 - Validation F1: 0.956096
# 200/200 [==============================] - 254s 1s/step - loss: 0.0603 - accuracy: 0.9837 - precision_3: 0.9853 - recall_3: 0.9956 - auc_3: 0.9897 - val_loss: 0.0624 - val_accuracy: 0.9784 - val_precision_3: 0.9771 - val_recall_3: 0.9978 - val_auc_3: 0.9949 - lr: 1.0000e-04
# Epoch 4/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9838 - precision_3: 0.9868 - recall_3: 0.9943 - auc_3: 0.9908
# Epoch 4: val_loss did not improve from 0.06074
#
# Epoch: 4 - Training Precision: 0.969656 - Training Recall: 0.83041 - Training F1: 0.882619
# Epoch: 4 - Validation Precision: 0.968176 - Validation Recall: 0.839444 - Validation F1: 0.888968
# 200/200 [==============================] - 254s 1s/step - loss: 0.0565 - accuracy: 0.9838 - precision_3: 0.9868 - recall_3: 0.9943 - auc_3: 0.9908 - val_loss: 0.1582 - val_accuracy: 0.9501 - val_precision_3: 0.9453 - val_recall_3: 0.9989 - val_auc_3: 0.9778 - lr: 1.0000e-04
# Epoch 5/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9853 - precision_3: 0.9873 - recall_3: 0.9954 - auc_3: 0.9925
# Epoch 5: val_loss improved from 0.06074 to 0.05648, saving model to FakenewsBERT.h5
#
# Epoch: 5 - Training Precision: 0.989098 - Training Recall: 0.984145 - Training F1: 0.986602
# Epoch: 5 - Validation Precision: 0.959115 - Validation Recall: 0.967179 - Validation F1: 0.963092
# 200/200 [==============================] - 280s 1s/step - loss: 0.0511 - accuracy: 0.9853 - precision_3: 0.9873 - recall_3: 0.9954 - auc_3: 0.9925 - val_loss: 0.0565 - val_accuracy: 0.9807 - val_precision_3: 0.9905 - val_recall_3: 0.9867 - val_auc_3: 0.9935 - lr: 1.0000e-04
# Epoch 6/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9920 - precision_3: 0.9928 - recall_3: 0.9978 - auc_3: 0.9944
# Epoch 6: val_loss did not improve from 0.05648
#
# Epoch: 6 - Training Precision: 0.989396 - Training Recall: 0.98816 - Training F1: 0.988777
# Epoch: 6 - Validation Precision: 0.94901 - Validation Recall: 0.968034 - Validation F1: 0.958209
# 200/200 [==============================] - 254s 1s/step - loss: 0.0322 - accuracy: 0.9920 - precision_3: 0.9928 - recall_3: 0.9978 - auc_3: 0.9944 - val_loss: 0.0636 - val_accuracy: 0.9779 - val_precision_3: 0.9916 - val_recall_3: 0.9822 - val_auc_3: 0.9916 - lr: 1.0000e-04
# Epoch 7/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9947 - precision_3: 0.9950 - recall_3: 0.9987 - auc_3: 0.9950
# Epoch 7: val_loss did not improve from 0.05648
#
# Epoch: 7 - Training Precision: 0.995878 - Training Recall: 0.988336 - Training F1: 0.992063
# Epoch: 7 - Validation Precision: 0.979258 - Validation Recall: 0.947286 - Validation F1: 0.962433
# 200/200 [==============================] - 277s 1s/step - loss: 0.0247 - accuracy: 0.9947 - precision_3: 0.9950 - recall_3: 0.9987 - auc_3: 0.9950 - val_loss: 0.0566 - val_accuracy: 0.9812 - val_precision_3: 0.9819 - val_recall_3: 0.9961 - val_auc_3: 0.9903 - lr: 1.0000e-04
# Epoch 8/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9955 - precision_3: 0.9956 - recall_3: 0.9991 - auc_3: 0.9960
# Epoch 8: val_loss did not improve from 0.05648
#
# Epoch: 8 - Training Precision: 0.997109 - Training Recall: 0.989548 - Training F1: 0.993284
# Epoch: 8 - Validation Precision: 0.975047 - Validation Recall: 0.942115 - Validation F1: 0.957681
# 200/200 [==============================] - 277s 1s/step - loss: 0.0204 - accuracy: 0.9955 - precision_3: 0.9956 - recall_3: 0.9991 - auc_3: 0.9960 - val_loss: 0.0605 - val_accuracy: 0.9788 - val_precision_3: 0.9803 - val_recall_3: 0.9950 - val_auc_3: 0.9890 - lr: 1.0000e-04
# Epoch 9/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9967 - precision_3: 0.9965 - recall_3: 0.9996 - auc_3: 0.9967
# Epoch 9: val_loss did not improve from 0.05648
#
# Epoch: 9 - Training Precision: 0.997295 - Training Recall: 0.990575 - Training F1: 0.9939
# Epoch: 9 - Validation Precision: 0.976004 - Validation Recall: 0.946731 - Validation F1: 0.960659
# 200/200 [==============================] - 278s 1s/step - loss: 0.0165 - accuracy: 0.9967 - precision_3: 0.9965 - recall_3: 0.9996 - auc_3: 0.9967 - val_loss: 0.0603 - val_accuracy: 0.9802 - val_precision_3: 0.9819 - val_recall_3: 0.9950 - val_auc_3: 0.9895 - lr: 1.0000e-04
# Epoch 10/10
# 200/200 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9972 - precision_3: 0.9970 - recall_3: 0.9996 - auc_3: 0.9970
# Epoch 10: val_loss improved from 0.05648 to 0.05495, saving model to FakenewsBERT.h5
#
# Epoch: 10 - Training Precision: 0.997574 - Training Recall: 0.992115 - Training F1: 0.994821
# Epoch: 10 - Validation Precision: 0.970675 - Validation Recall: 0.963526 - Validation F1: 0.967058
# 200/200 [==============================] - 281s 1s/step - loss: 0.0142 - accuracy: 0.9972 - precision_3: 0.9970 - recall_3: 0.9996 - auc_3: 0.9970 - val_loss: 0.0550 - val_accuracy: 0.9831 - val_precision_3: 0.9884 - val_recall_3: 0.9917 - val_auc_3: 0.9922 - lr: 1.0000e-04

# %% [markdown]
# ### Evaluation Graphs

# %%
clf.plot_learning_curve()
